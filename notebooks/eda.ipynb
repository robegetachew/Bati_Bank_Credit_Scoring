# %%
#import the module
import sys
sys.path.append(r'C:\Users\user\Desktop\Kifiya\Bati_Bank_Credit_Scoring\scripts')

import eda_analysis as eda

# %% [markdown]
# # Load the data

# %%
file_path = r'C:\Users\Eyor.G\Downloads\Technical Content-20250122T091440Z-001\Technical Content\data\data.csv'
data = eda.data_loader(file_path)
data.head(5)
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %% [markdown]
# # Dataset Overview

# %%
eda.overview_data(data)
# Out:
# Dataset Overview:
# Number of Rows: 95662
# Number of Columns: 16
#
# Data Types:
# TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object
#
# Missing Values:
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# Amount                  0
# ...

# %% [markdown]
# # Summary Statistics

# %%
eda.summary_statistics(data)
# Out:
# Summary Statistics:
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000

# %% [markdown]
# # Visualize Numerical Features

# %%
numerical_columns = ["Amount", "Value"]
eda.visualize_numerical_distribution(data, numerical_columns)

# %% [markdown]
# # Visualize Categorical Features

# %%
categorical_columns = [
    "CurrencyCode", "CountryCode", "ProviderId", "ProductCategory", "ChannelId", "FraudResult"
]
eda.visualize_categorical_distribution(data, categorical_columns)

# %% [markdown]
# # Correlation Analysis

# %%
eda.correlation_analysis(data, numerical_columns)

# %% [markdown]
# # Identify Missing Values

# %%
eda.identify_missing_values(data)
# Out:
# Missing Values:
# Series([], dtype: int64)

# %% [markdown]
# # Outlier Detection

# %%
eda.detect_outliers(data, numerical_columns)
